# %%
include("TortoiseSat.jl")

# %%
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
#   Installed LightXML ───────────────────── v0.8.1
#   Installed DiffEqFinancial ────────────── v2.4.0
#   Installed DifferentialEquations ──────── v6.12.0
#   Installed SafeTestsets ───────────────── v0.0.1
#   Installed ForwardDiff ────────────────── v0.10.9
#   Installed SatelliteToolbox ───────────── v0.7.1
#   Installed OpenSpecFun_jll ────────────── v0.5.3+3
#   Installed DiffEqPhysics ──────────────── v3.5.0
#   Installed UnPack ─────────────────────── v1.0.1
#   Installed JuliaVariables ─────────────── v0.2.0
#   Installed RecursiveFactorization ─────── v0.1.3
#   Installed Plots ──────────────────────── v0.29.8
#   Installed IterativeSolvers ───────────── v0.8.4
#   Installed MathProgBase ───────────────── v0.7.8
#   Installed AxisAlgorithms ─────────────── v1.0.0
#   Installed JSONSchema ─────────────────── v0.3.0
# ...
